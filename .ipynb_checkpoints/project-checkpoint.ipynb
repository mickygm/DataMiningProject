# %%
import os
from pathlib import Path
import librosa
import soundfile as sf
import numpy as np

REAL_INPUT_DIR = "data/realAudio" 
FAKE_INPUT_DIR = "data/fakeAudio"

CLEAN_REAL_DIR = "data/cleanReal" 
CLEAN_FAKE_DIR = "data/cleanFake"

TARGET_SR = 16000
TARGET_DURATION = 4.0



def standardizeAudio(in_path, out_path, sr=TARGET_SR, duration=TARGET_DURATION):
    # Load WAV
    y, _ = librosa.load(in_path, sr=sr, mono=True)
    # Trim or pad to target duration
    target_len = int(sr * duration)
    if len(y) > target_len:
        # Trim to target duration
        y = y[:target_len]
    else:
        # Pad and pad if too short
        pad_total = target_len - len(y)
        pad_left = pad_total // 2
        pad_right = pad_total - pad_left
        y = np.pad(y, (pad_left, pad_right))
    # Ensure output folder exists
    os.makedirs(os.path.dirname(out_path), exist_ok=True)
    # Save standardized WAV
    sf.write(out_path, y, sr)
    print(f"Saved: {out_path}")


def processFolder(input_dir, output_dir):
    input_dir = Path(input_dir)
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    audio_files = list(input_dir.glob("*.wav"))
    if not audio_files:
        print(f"No .wav files found in {input_dir}")
        return
    for f in audio_files:
        out_name = f.stem + "Clean.wav"
        out_path = output_dir / out_name
        standardizeAudio(str(f), str(out_path))


def main():
    print("Processing REAL WAV audio")
    processFolder(REAL_INPUT_DIR, CLEAN_REAL_DIR)

    print("\nProcessing FAKE WAV audio")
    processFolder(FAKE_INPUT_DIR, CLEAN_FAKE_DIR)


if __name__ == "__main__":
    main()
# Out:
# Processing REAL WAV audio
# Saved: data/cleanReal/audio8Clean.wav
# Saved: data/cleanReal/audio18Clean.wav
# Saved: data/cleanReal/audio19Clean.wav
# Saved: data/cleanReal/audio9Clean.wav
# Saved: data/cleanReal/audio20Clean.wav
# Saved: data/cleanReal/audio2Clean.wav
# Saved: data/cleanReal/audio12Clean.wav
# Saved: data/cleanReal/audio13Clean.wav
# Saved: data/cleanReal/audio3Clean.wav
# Saved: data/cleanReal/audio11Clean.wav
# Saved: data/cleanReal/audio1Clean.wav
# Saved: data/cleanReal/audio10Clean.wav
# Saved: data/cleanReal/audio14Clean.wav
# Saved: data/cleanReal/audio4Clean.wav
# Saved: data/cleanReal/audio5Clean.wav
# Saved: data/cleanReal/audio15Clean.wav
# Saved: data/cleanReal/audio7Clean.wav
# Saved: data/cleanReal/audio17Clean.wav
# Saved: data/cleanReal/audio16Clean.wav
# Saved: data/cleanReal/audio6Clean.wav
#
# Processing FAKE WAV audio
# Saved: data/cleanFake/audio27Clean.wav
# Saved: data/cleanFake/audio26Clean.wav
# Saved: data/cleanFake/audio8Clean.wav
# Saved: data/cleanFake/audio18Clean.wav
# Saved: data/cleanFake/audio24Clean.wav
# Saved: data/cleanFake/audio25Clean.wav
# Saved: data/cleanFake/audio19Clean.wav
# Saved: data/cleanFake/audio9Clean.wav
# Saved: data/cleanFake/audio21Clean.wav
# Saved: data/cleanFake/audio20Clean.wav
# Saved: data/cleanFake/audio22Clean.wav
# Saved: data/cleanFake/audio23Clean.wav
# Saved: data/cleanFake/audio2Clean.wav
# Saved: data/cleanFake/audio12Clean.wav
# Saved: data/cleanFake/audio13Clean.wav
# Saved: data/cleanFake/audio3Clean.wav
# Saved: data/cleanFake/audio11Clean.wav
# Saved: data/cleanFake/audio1Clean.wav
# Saved: data/cleanFake/audio0Clean.wav
# Saved: data/cleanFake/audio10Clean.wav
# Saved: data/cleanFake/audio14Clean.wav
# Saved: data/cleanFake/audio4Clean.wav
# Saved: data/cleanFake/audio28Clean.wav
# Saved: data/cleanFake/audio29Clean.wav
# Saved: data/cleanFake/audio5Clean.wav
# Saved: data/cleanFake/audio15Clean.wav
# Saved: data/cleanFake/audio7Clean.wav
# Saved: data/cleanFake/audio17Clean.wav
# Saved: data/cleanFake/audio16Clean.wav
# Saved: data/cleanFake/audio6Clean.wav

# %%
import os
from pathlib import Path

import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# ==== EDIT THESE PATHS ====
INPUT_DIR = "data/fakeAudio"       # folder with .wav files
OUTPUT_DIR = "data/fakeSpect"      # folder to save .png images
SAMPLE_RATE = 16000
# ===========================


def create_spectrogram(wav_path, png_path, sr=SAMPLE_RATE):
    """Load a WAV file, keep only first 4 seconds, create log-mel spectrogram, and save PNG."""
    print(f"Processing: {wav_path}")

    # Load WAV audio
    y, sr = librosa.load(wav_path, sr=sr, mono=True)

    # ============ KEEP ONLY FIRST 4 SECONDS ============
    max_len = int(4.0 * sr)
    y = y[:max_len]
    # ====================================================

    # Mel spectrogram
    S = librosa.feature.melspectrogram(
        y=y, sr=sr,
        n_fft=2048,
        hop_length=512,
        n_mels=128
    )
    S_db = librosa.power_to_db(S, ref=np.max)

    # Plot
    plt.figure(figsize=(8, 3))
    librosa.display.specshow(
        S_db, sr=sr, hop_length=512,
        x_axis="time", y_axis="mel"
    )
    plt.colorbar(label="dB")
    plt.title(Path(wav_path).name)
    plt.tight_layout()

    # Save
    os.makedirs(os.path.dirname(png_path), exist_ok=True)
    plt.savefig(png_path, dpi=150)
    plt.close()

    print(f"Saved: {png_path}")


def main():
    input_dir = Path(INPUT_DIR)
    output_dir = Path(OUTPUT_DIR)

    wav_files = sorted(input_dir.glob("*.wav"))
    if not wav_files:
        print(f"No .wav files found in {input_dir}")
        return

    for wav_file in wav_files:
        out_name = wav_file.stem + "_spect.png"
        out_path = output_dir / out_name
        create_spectrogram(str(wav_file), str(out_path))


if __name__ == "__main__":
    main()
# Out:
# Processing: data/fakeAudio/audio0.mp4
# Saved: data/fakeSpect/audio0_spect.png
# Processing: data/fakeAudio/audio1.mp4
# /var/folders/l1/991h4ps92ps2j8xfn3ycczzm0000gn/T/ipykernel_9919/2863865619.py:21: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(mp4_path, sr=sr, mono=True)
# /opt/anaconda3/lib/python3.13/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Saved: data/fakeSpect/audio1_spect.png
# Processing: data/fakeAudio/audio10.mp4
# Saved: data/fakeSpect/audio10_spect.png
# Processing: data/fakeAudio/audio11.mp4
# Saved: data/fakeSpect/audio11_spect.png
# Processing: data/fakeAudio/audio12.mp4
# Saved: data/fakeSpect/audio12_spect.png
# Processing: data/fakeAudio/audio13.mp4
# Saved: data/fakeSpect/audio13_spect.png
# Processing: data/fakeAudio/audio14.mp4
# Saved: data/fakeSpect/audio14_spect.png
# Processing: data/fakeAudio/audio15.mp4
# Saved: data/fakeSpect/audio15_spect.png
# Processing: data/fakeAudio/audio16.mp4
# Saved: data/fakeSpect/audio16_spect.png
# Processing: data/fakeAudio/audio17.mp4
# Saved: data/fakeSpect/audio17_spect.png
# Processing: data/fakeAudio/audio18.mp4
# Saved: data/fakeSpect/audio18_spect.png
# Processing: data/fakeAudio/audio19.mp4
# Saved: data/fakeSpect/audio19_spect.png
# Processing: data/fakeAudio/audio2.mp4
# Saved: data/fakeSpect/audio2_spect.png
# Processing: data/fakeAudio/audio20.mp4
# Saved: data/fakeSpect/audio20_spect.png
# Processing: data/fakeAudio/audio21.mp4
# Saved: data/fakeSpect/audio21_spect.png
# Processing: data/fakeAudio/audio22.mp4
# Saved: data/fakeSpect/audio22_spect.png
# Processing: data/fakeAudio/audio23.mp4
# Saved: data/fakeSpect/audio23_spect.png
# Processing: data/fakeAudio/audio24.mp4
# Saved: data/fakeSpect/audio24_spect.png
# Processing: data/fakeAudio/audio25.mp4
# Saved: data/fakeSpect/audio25_spect.png
# Processing: data/fakeAudio/audio26.mp4
# Saved: data/fakeSpect/audio26_spect.png
# Processing: data/fakeAudio/audio27.mp4
# Saved: data/fakeSpect/audio27_spect.png
# Processing: data/fakeAudio/audio28.mp4
# Saved: data/fakeSpect/audio28_spect.png
# Processing: data/fakeAudio/audio29.mp4
# Saved: data/fakeSpect/audio29_spect.png
# Processing: data/fakeAudio/audio3.mp4
# Saved: data/fakeSpect/audio3_spect.png
# Processing: data/fakeAudio/audio4.mp4
# Saved: data/fakeSpect/audio4_spect.png
# Processing: data/fakeAudio/audio5.mp4
# Saved: data/fakeSpect/audio5_spect.png
# Processing: data/fakeAudio/audio6.mp4
# Saved: data/fakeSpect/audio6_spect.png
# Processing: data/fakeAudio/audio7.mp4
# Saved: data/fakeSpect/audio7_spect.png
# Processing: data/fakeAudio/audio8.mp4
# Saved: data/fakeSpect/audio8_spect.png
# Processing: data/fakeAudio/audio9.mp4
# Saved: data/fakeSpect/audio9_spect.png

# %%
import os
import glob
import numpy as np
import pandas as pd
import librosa

def extract_spectral_fingerprint(filepath, sr=16000, n_mfcc=13, target_duration=3.0):
    """
    Minimal spectral fingerprint for one audio file.
    STANDARDIZES AUDIO TO FIXED LENGTH (center pad/crop).
    """

    # Load audio
    y, sr = librosa.load(filepath, sr=sr, mono=True)

    # ==== FIXED-LENGTH STANDARDIZATION ====
    target_len = int(target_duration * sr)

    if len(y) < target_len:
        # Center padding
        pad_total = target_len - len(y)
        pad_left = pad_total // 2
        pad_right = pad_total - pad_left
        y = np.pad(y, (pad_left, pad_right))
    elif len(y) > target_len:
        # Center cropping
        start = (len(y) - target_len) // 2
        y = y[start:start + target_len]
    # =======================================

    features = {}

    # --- MFCC ---
    mfcc = librosa.feature.mfcc(
        y=y, sr=sr, n_mfcc=n_mfcc,
        dct_type=2, norm='ortho'   # for stable reproducibility
    )

    for i in range(n_mfcc):
        features[f"mfcc_{i+1}_mean"] = float(mfcc[i].mean())
        features[f"mfcc_{i+1}_std"] = float(mfcc[i].std())

    # --- Spectral features ---
    centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, roll_percent=0.95)
    flatness = librosa.feature.spectral_flatness(y=y)

    features["spec_centroid_mean"] = float(centroid.mean())
    features["spec_centroid_std"] = float(centroid.std())

    features["spec_bandwidth_mean"] = float(bandwidth.mean())
    features["spec_bandwidth_std"] = float(bandwidth.std())

    features["spec_rolloff95_mean"] = float(rolloff.mean())
    features["spec_rolloff95_std"] = float(rolloff.std())

    features["spec_flatness_mean"] = float(flatness.mean())
    features["spec_flatness_std"] = float(flatness.std())

    # --- Temporal / energy ---
    zcr = librosa.feature.zero_crossing_rate(y)
    rms = librosa.feature.rms(y=y)
    flux = librosa.onset.onset_strength(y=y, sr=sr)

    features["zcr_mean"] = float(zcr.mean())
    features["zcr_std"] = float(zcr.std())

    features["rms_mean"] = float(rms.mean())
    features["rms_std"] = float(rms.std())

    features["spec_flux_mean"] = float(flux.mean())
    features["spec_flux_std"] = float(flux.std())

    return features


def process_real_fake_folders(real_dir, fake_dir):
    """
    real_dir  -> label 'real'
    fake_dir  -> label 'deepfake'
    Only processes .mp4 files.
    """
    rows = []

    # Real
    for filepath in glob.glob(os.path.join(real_dir, "*.mp4")):
        print(f"Processing (real): {filepath}")
        feats = extract_spectral_fingerprint(filepath)
        feats["label"] = "real"
        feats["file"] = os.path.basename(filepath)
        rows.append(feats)

    # Fake
    for filepath in glob.glob(os.path.join(fake_dir, "*.mp4")):
        print(f"Processing (deepfake): {filepath}")
        feats = extract_spectral_fingerprint(filepath)
        feats["label"] = "deepfake"
        feats["file"] = os.path.basename(filepath)
        rows.append(feats)

    return pd.DataFrame(rows)


if __name__ == "__main__":
    # Set these to your actual folders
    REAL_DIR = "data/realAudio"
    FAKE_DIR = "data/fakeAudio"
    OUTPUT_CSV = "data/spectralFingerprints.csv"

    df = process_real_fake_folders(REAL_DIR, FAKE_DIR)
    print("Extracted features shape:", df.shape)
    print(df.head())

    df.to_csv(OUTPUT_CSV, index=False)
    print(f"Saved features to {OUTPUT_CSV}")
# Out:
# Processing (real): data/realAudio/audio13.mp4
# Processing (real): data/realAudio/audio3.mp4
# Processing (real): data/realAudio/audio2.mp4
# Processing (real): data/realAudio/audio12.mp4
# Processing (real): data/realAudio/audio10.mp4
# Processing (real): data/realAudio/audio11.mp4
# Processing (real): data/realAudio/audio1.mp4
# Processing (real): data/realAudio/audio5.mp4
# Processing (real): data/realAudio/audio15.mp4
# Processing (real): data/realAudio/audio14.mp4
# Processing (real): data/realAudio/audio4.mp4
# Processing (real): data/realAudio/audio16.mp4
# Processing (real): data/realAudio/audio6.mp4
# Processing (real): data/realAudio/audio7.mp4
# /var/folders/l1/991h4ps92ps2j8xfn3ycczzm0000gn/T/ipykernel_9919/2538701157.py:14: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(filepath, sr=sr, mono=True)
# /opt/anaconda3/lib/python3.13/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing (real): data/realAudio/audio17.mp4
# Processing (real): data/realAudio/audio19.mp4
# Processing (real): data/realAudio/audio9.mp4
# Processing (real): data/realAudio/audio8.mp4
# Processing (real): data/realAudio/audio18.mp4
# Processing (real): data/realAudio/audio20.mp4
# Processing (deepfake): data/fakeAudio/audio13.mp4
# Processing (deepfake): data/fakeAudio/audio3.mp4
# Processing (deepfake): data/fakeAudio/audio2.mp4
# Processing (deepfake): data/fakeAudio/audio12.mp4
# Processing (deepfake): data/fakeAudio/audio0.mp4
# Processing (deepfake): data/fakeAudio/audio10.mp4
# Processing (deepfake): data/fakeAudio/audio11.mp4
# Processing (deepfake): data/fakeAudio/audio1.mp4
# Processing (deepfake): data/fakeAudio/audio5.mp4
# Processing (deepfake): data/fakeAudio/audio15.mp4
# Processing (deepfake): data/fakeAudio/audio29.mp4
# Processing (deepfake): data/fakeAudio/audio28.mp4
# Processing (deepfake): data/fakeAudio/audio14.mp4
# Processing (deepfake): data/fakeAudio/audio4.mp4
# Processing (deepfake): data/fakeAudio/audio16.mp4
# Processing (deepfake): data/fakeAudio/audio6.mp4
# Processing (deepfake): data/fakeAudio/audio7.mp4
# Processing (deepfake): data/fakeAudio/audio17.mp4
# Processing (deepfake): data/fakeAudio/audio26.mp4
# Processing (deepfake): data/fakeAudio/audio27.mp4
# Processing (deepfake): data/fakeAudio/audio19.mp4
# Processing (deepfake): data/fakeAudio/audio9.mp4
# Processing (deepfake): data/fakeAudio/audio25.mp4
# Processing (deepfake): data/fakeAudio/audio24.mp4
# Processing (deepfake): data/fakeAudio/audio8.mp4
# Processing (deepfake): data/fakeAudio/audio18.mp4
# Processing (deepfake): data/fakeAudio/audio20.mp4
# Processing (deepfake): data/fakeAudio/audio21.mp4
# Processing (deepfake): data/fakeAudio/audio23.mp4
# Processing (deepfake): data/fakeAudio/audio22.mp4
# Extracted features shape: (50, 42)
#    mfcc_1_mean  mfcc_1_std  mfcc_2_mean  mfcc_2_std  mfcc_3_mean  mfcc_3_std  \
# 0  -402.156128   82.165367   123.720047   39.885605     4.289783   38.138481
# 1  -378.605804   76.566292   130.093704   44.255821   -14.475707   32.276760
# 2  -461.762756  113.722221   107.666069   37.762432    14.081129   32.458847
# 3  -380.284271   82.454964   119.977615   42.173016   -12.475291   35.589195
# 4  -443.119843   90.016106   108.634804   44.897274    -1.141207   41.408356
#
#    mfcc_4_mean  mfcc_4_std  mfcc_5_mean  mfcc_5_std  ...  spec_flatness_mean  \
# 0    25.679247   33.680641    -1.022359   19.722780  ...            0.004995
# 1    18.226503   30.643219    -0.845056   14.499025  ...            0.008448
# 2    31.125019   24.178225     1.095101   20.082458  ...            0.010509
# 3    12.823211   30.150129     1.162471   17.687782  ...            0.008045
# 4    33.580574   27.052156     0.607164   20.334476  ...            0.012699
#
#    spec_flatness_std  zcr_mean   zcr_std  rms_mean   rms_std  spec_flux_mean  \
# 0           0.020676  0.069341  0.072614  0.020827  0.011120        2.329499
# 1           0.023782  0.085605  0.068358  0.015516  0.005555        2.693065
# 2           0.032101  0.071684  0.073129  0.014382  0.012514        1.993284
# 3           0.023437  0.086597  0.079121  0.019780  0.010240        2.636394
# 4           0.036574  0.092119  0.098697  0.014349  0.007137        2.491531
#
#    spec_flux_std  label         file
# 0       2.373902   real  audio13.mp4
# 1       3.100258   real   audio3.mp4
# 2       2.166436   real   audio2.mp4
# 3       2.545630   real  audio12.mp4
# 4       2.507914   real  audio10.mp4
#
# [5 rows x 42 columns]
# Saved features to data/spectralFingerprints.csv

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix

# Path to your CSV from the feature-extraction script
CSV_PATH = "data/spectralFingerprints.csv"

def main():
    # Load data
    df = pd.read_csv(CSV_PATH)

    # Drop non-feature columns
    X = df.drop(columns=["label", "file"])
    y = df["label"]

    # Train/test split
    X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=0.5,
        random_state=42,
        stratify=y
    )

    # Pipeline: standardize features -> KNN
    clf = Pipeline([
        ("scaler", StandardScaler()),
        ("knn", KNeighborsClassifier(n_neighbors=5))
    ])

    # Train
    clf.fit(X_train, y_train)

    # Evaluate
    acc = clf.score(X_test, y_test)
    print(f"Accuracy: {acc:.4f}\n")

    y_pred = clf.predict(X_test)

    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))

if __name__ == "__main__":
    main()
# Out:
# Accuracy: 0.8800
#
# Confusion Matrix:
# [[15  0]
#  [ 3  7]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     deepfake       0.83      1.00      0.91        15
#         real       1.00      0.70      0.82        10
#
#     accuracy                           0.88        25
#    macro avg       0.92      0.85      0.87        25
# weighted avg       0.90      0.88      0.87        25

# %%
import os
import glob
import numpy as np
from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, confusion_matrix


def load_spectrogram(filepath, size=(128, 128)):
    """
    Load a PNG spectrogram, convert to grayscale, resize,
    normalize, and flatten to 1D.
    """
    img = Image.open(filepath).convert("L")  # grayscale
    img = img.resize(size)                  # enforce fixed size
    arr = np.array(img, dtype=np.float32)

    # normalize to [0,1]
    arr /= 255.0

    # flatten into a 1D feature vector
    return arr.flatten()


def load_spectrogram_dataset(real_dir, fake_dir, img_size=(128,128)):
    X, y, files = [], [], []

    # Real spectrograms
    for filepath in glob.glob(os.path.join(real_dir, "*.png")):
        feat = load_spectrogram(filepath, size=img_size)
        X.append(feat)
        y.append("real")
        files.append(os.path.basename(filepath))

    # Fake spectrograms
    for filepath in glob.glob(os.path.join(fake_dir, "*.png")):
        feat = load_spectrogram(filepath, size=img_size)
        X.append(feat)
        y.append("deepfake")
        files.append(os.path.basename(filepath))

    X = np.vstack(X)
    y = np.array(y)
    files = np.array(files)

    print("Dataset loaded.")
    print("Feature matrix shape:", X.shape)
    print("Class counts:")
    print("  real:", np.sum(y=="real"))
    print("  deepfake:", np.sum(y=="deepfake"))

    return X, y, files


if __name__ == "__main__":
    REAL_SPECT_DIR = "data/realSpect"
    FAKE_SPECT_DIR = "data/fakeSpect"

    # Load data
    X, y, files = load_spectrogram_dataset(REAL_SPECT_DIR, FAKE_SPECT_DIR)

    # Split dataset
    X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        test_size=0.3,
        random_state=42,
        stratify=y
    )

    # KNN pipeline with StandardScaler
    clf = Pipeline([
        ("scaler", StandardScaler()),
        ("knn", KNeighborsClassifier(n_neighbors=5))
    ])

    clf.fit(X_train, y_train)

    # Evaluate
    acc = clf.score(X_test, y_test)
    print(f"\nAccuracy: {acc:.4f}")

    y_pred = clf.predict(X_test)

    print("\nConfusion Matrix:")
    print(confusion_matrix(y_test, y_pred, labels=["real", "deepfake"]))

    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, labels=["real", "deepfake"]))
# Out:
# Dataset loaded.
# Feature matrix shape: (50, 16384)
# Class counts:
#   real: 20
#   deepfake: 30
#
# Accuracy: 0.9333
#
# Confusion Matrix:
# [[6 0]
#  [1 8]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         real       0.86      1.00      0.92         6
#     deepfake       1.00      0.89      0.94         9
#
#     accuracy                           0.93        15
#    macro avg       0.93      0.94      0.93        15
# weighted avg       0.94      0.93      0.93        15
